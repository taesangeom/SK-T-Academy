# %% [markdown]
# <a href="https://colab.research.google.com/github/taesangeom/SK-T-Academy/blob/main/Coding_Test/12_%ED%83%90%EC%83%89_%EA%B8%B0%EB%B3%B8%EA%B0%9C%EB%85%90_%EC%9E%AC%EA%B7%80%ED%95%A8%EC%88%98_%EC%9E%90%EB%A3%8C%EA%B5%AC%EC%A1%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#코테 7문제:

# 1,2,3 번 문제 : 구현 + 잡다함
# 4,5,6,7 번 문제 : 알고리즘
# -> 내용: 탐색, 최단거리 알고리즘 + 여러 상황에 녹아들어감

# %%
# ===> while 조건 : 조건이 참일 때 까지!!!!!!!
#                   - for 값/갯수 중심!!!!!
#                   - while 조건 중심!!!!!!
#                  ===> 빠져나갈 조건에 대한 값/ 조건상황!!!!!! 구조적인 부분을 설계!!!!!

#반목문에서 pass,continue,break 잘 사용하자

# - pass : 아래 내용 skip ==> 형식상 맞춤을 위해서 사용!!
#          코테에서는 거의 pass는 사용을 안 하는 경우가 많아요!!
# - continue : for/while에서 다음 순번으로 넘길 때 사용!!! if,else 들여쓰기 상관없이 반복문 기준으로 밑에 다 생략
# - break    : 반복문for/while을 그냥 다음 것들이 남아도 완전 세우는 역할!!!

# %%
# pass 예
# ==> 대충 생각하면 건너띄기,,,,,,,,
#     실제적으로는 코드상 pass가 있는 그 한줄만 pass
#     아래 예와 같은 코드는 거의`~~~~안 씀. 그냥 틀 맞추기이다.!!
#     else:
#         pass

a = [3,4,5,6,7,8,9]
for i in a:
    print("체크 전의 값:",i)
    # 중간에 혹시 5가 나온다면 뒤에 뭐가 있더라도 때려치자!!!
    if i == 5:
        print(i)
        pass
        print(i+10000)
    print("PASSSSSSSSSSSSSSSSSSSS")
# Out:
# 체크 전의 값: 3
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 4
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 5
# 5
# 10005
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 6
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 7
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 8
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 9
# PASSSSSSSSSSSSSSSSSSSS

# %%
# continue 예
a = [3,4,5,6,7,8,9]
for i in a:
    print("체크 전의 값:",i)
    # 중간에 혹시 5가 나온다면 뒤에 뭐가 있더라도 때려치자!!!
    if i == 5:
        print(i)
        continue
        print(i+10000)
    print("PASSSSSSSSSSSSSSSSSSSS")
# Out:
# 체크 전의 값: 3
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 4
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 5
# 5
# 체크 전의 값: 6
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 7
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 8
# PASSSSSSSSSSSSSSSSSSSS
# 체크 전의 값: 9
# PASSSSSSSSSSSSSSSSSSSS

# %%
# 정리 : 프로그램의 구조 ==> 반복문(for/ while)
#                               + 자세한구조 if
#                                   : break, pass. continue
# ===> 원하는 목적대로 반복문과 제어문이 수행할 수 있도록 명확하게 구조!!!!
# ++++ 탐색/ 최단거리 이러한 부분을 더 신경써서 사용을 해야함!!!

# %%
# 사전내용 2: 자료구조형 : 스케줄링, Stack, Queue

# %%
# 기본적인 내용 : 값을 처리하는 방식 -> 스케줄러 사용하는 -> 새로운 해야할 일 추가 , 한 것들에 대한 제거

#Stack : 지하철 -> Last in First Out : LIFO
#-> 새로운 것들이 출구쪽에 쌓임 -> 맨 뒤가 출구임
# 새로운 원소 추가 -> append() / 맨 뒤 원소 제거 -> pop()

#Queue : 줄 서기 -> First IN First Out : FIFO
#-> 새로운 것 맨 뒤부터 쌓이는데, 출구가 앞부터임
# 새로운 것 -> append()
#제거 -> pop(0) 맨 앞부터 탈출    -> 코테에서는 속도문제

# %%
a=[1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.append(7)
a.append(8)
a
# Out:
# [1, 2, 3, 4, 5, 7, 8]

# %%
#stack 처리 -> pop() -> 맨 뒤 8 제거
a.pop()
a
# Out:
# [1, 2, 3, 4, 5, 7]

# %%
a.pop()
a
# Out:
# [1, 2, 3, 4]

# %%
a.append(5)

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.pop(0) #queue 처리 -> 맨 앞인 1원소가 탈출
# Out:
# 1

# %%
a
# Out:
# [2, 3, 4, 5]

# %%
# 참고: 파이썬 리스트로 대표적인 자료구조 Queue를 구현 -> 파이썬 언어의 특성상 속도이슈 발생할 수 밖에 없음. 속도이슈가 내 탓이 아니다

#코테에서 쓸거면 deque 패키지 사용하자 -> 새로운 deque 자료형

#참고 시간속도 : pandas > list > deque , deque가 제일 빠름

# %%
#코테에서만 쓰는 재귀함수 ㅎㅎ
# -> 일반적인 코드나 데이터분석에서 거의 사용하지 않지만, 코테에서는 사용해야함.
#이유: 구조적인 반복을 코드화하기 유용해서. -> 동적 프로그래밍 , Depth First Search  재귀함수
# 구조적으로 뭔가 기능이 반복될 때 사용
#DFS (stack기반) -> 재귀함수로 구현가능 / BFS(queue 기반) -> 재귀 X

# %%
#참고 : 파이썬의 재귀함수는 제한이 걸려있음. -> while 종료조건에 대한 설계 필요

def recursive_func():
  print('재귀함수를 호출합니다.')
  recursive_func()

# %%
# 재귀함수 예 ) 4!
# 직접계산하는 과정 : 4!=4*3*2*1

# 1) for문
n = 4
fact = 1
for i in range(1,n+1,1):
    fact *= i
print(fact)
# Out:
# 24

# %%
# ===> ! 할 일 : 정의가 아니라 기능 중심 바로보자!!!!
#      점화식
#      n! = n * (n-1)!,   1! =1
# ===> "기능 중심" 의 "규칙"!!!!!!!
# ===> 바로 코드화!!!!
def my_fact(n):
    #  호출이 되었는지 체크 --> print
    print("MyFact호출?"+ str(n))
    if n <= 1:
        return 1
    else:
        return n*my_fact(n-1)
# ---> 기능적인 규칙성을 그냥 코드화 작업이 가능함!!!!
#      코드가 상당히 직관적으로 작성이 됨!!!!!
# ===> 규칙성이 있는 것들에 대한 관계 중심의 코드 작성에 용이함!!!
#      퀵정렬, 탐색(dfs), dp, 규칙적인 부분 구현 : 코테용



# 맨 마지막으로 호출되는 것부터 해결해야만 거슬러 올라감 ->  stack의 구조와 동일

# %%
my_fact(4)
# Out:
# MyFact호출?4
# MyFact호출?3
# MyFact호출?2
# MyFact호출?1
# 24

# %%
#재귀함수 : STACK 처럼 처리를 한다.
#관점: 기능 중심의 관계성, 규칙성을 간단하게 코드화
# 종료조건, 초기화조건

# 재귀함수 : 자기 자신을 계속 호출하는 구조
# 해결의 순서는 맨 마지막으로 호출된 친구부터 해결해서 거슬러 올라감 = stack
# DFS stack 형식을 사용 -> 탐색의 규칙/기능적인 재귀함수로 구현이 가능함
#BFS 는 재귀함수 사용하면 안됨 X -> queue 기반구조

# %%
#그래프에 대한 코드화 작업
## 기본적인 대상 : 지도, 네트워크, 연결성..
# ==> 현실적인 현상들을 점/선으로 추상화!!!
# ==> 추상화 되어 있는 그래프들을 어떻게 코드화(코드 표현 방식)
# 1) 행렬 방식으로 구현
# 2) 리스트 방식으로 구현

# %%
# 탐색 문제 : 모든 경우들을 다 체크하는 문제!!!!!
# -> 수학적으로 모든 경우의 수를 고려해보는 문제
# 지도가 있는 경우 -> 좀 명확한 문제 유형
#평면, 다양한 유형들을 정리
#여러 유형의 문제들을 많이 풀자 ( 왜 탐색의 문제인지 이해 , 여러 탐색 알고리즘 중에서 어떤 방식이 좋은지)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
INF = 999999999


graph = [
    [0, 7, 5],
    [7, 0, INF],
    [5, INF, 0]
]

print(graph)
# Out:
# [[0, 7, 5], [7, 0, 999999999], [5, 999999999, 0]]

# %%
#0번 도시에서 1번 도시가 연결되었나요?
graph[0][1]
# Out:
# 7

# %%
#행렬로 표현을 한다면 행: 시작점 (정방행렬 n*n)
# 열 : 도착점  ->  지도[시작점][도착점]

#생 파이썬의 입장에서 지도를 표현하는 인접행렬을 바라본다면 -> *****지도[시작점][도착점]*******

#참고 : 명시적인 2d numpy,dataframe,tensorflow 다른 패키지

# %%
#인접 리스트 방식 : 연결성만 바라보고 구성=> 컴팩트하게

#인접 리스트 방식의 코드화 - 리스트 활용
g_1 = [
    [ (1,7), (2,5)], # --> 0번 도시의 연결 리스트업!!!
    [(0,7)],         # --> 1번 도시의 연결 리스트업!!!
    [(0,5)]          # --> 2번 도시의 연결 리스트업!!!
]
g_1
# Out:
# [[(1, 7), (2, 5)], [(0, 7)], [(0, 5)]]

# %%
# --> 0번 도시하고 1번 도시가 연결되어 있나요?
g_1[0][0][1]
# ===> 구체적인 연결성에 대한 질문에 있어서는 직접 탐색!!!!
#      좀 행렬표현 방식보다는 직관성이 떨어질 수 있음!!!
# Out:
# 7

# %%
#인접리스트방식의 코드화 : DICT 활용
g_dict = {
    "0":[("1",7), ("2",5)],
    "1":[("0",7)],
    "2":[("0",5)]
}
g_dict
# Out:
# {'0': [('1', 7), ('2', 5)], '1': [('0', 7)], '2': [('0', 5)]}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# --> 0버 도시하고, 1번 도시가 연결되어 있나요ㅕ?
# ==> 연결이 엄청 많을 때,,,,Dict 조금 더 빠르지 않을까!!!!!
g_dict["0"][0][1]
# Out:
# 7

# %%
# 참고) 인접리스트 방식을 리스트 자료형으로 코드화할 때
# ==> 0번 도시가 없다고 하면,,가상의 0번 도시를 만들어서
#     도시번호하고 인덱스를 일치시키는 방식도 있다!!!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
g_2 = [
    [],              # --> 가상의 0번 도시를 세팅!!!!!
    [ (2,7), (3,5)], # --> 1번 도시의 연결 리스트업!!!
    [(1,7)],         # --> 2번 도시의 연결 리스트업!!!
    [(1,5)]          # --> 3번 도시의 연결 리스트업!!!
]
g_2
# Out:
# [[], [(2, 7), (3, 5)], [(1, 7)], [(1, 5)]]

# %%
g_2[1]
# Out:
# [(2, 7), (3, 5)]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# DFS 예제
# 0) 탐색을 지도에서 해야하므로 지도를 코드화!!!!
#    ==> 인접리스트 방식 리스트 자료형으로 구현!!!!!
#    --> 0번 도시를 가상으로 생성해서 추가!!!!!
#    --> 단순히 연결에 대한 정보만!!!거리 X
graph_list = [
    [], #<--가상의 0번 도시으므로 연결이 없음 : 인덱스 더미 처리용
    [2,3,8], # <--- 1번 도시의 연결
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]
graph_list
# Out:
# [[], [2, 3, 8], [1, 7], [1, 4, 5], [3, 5], [3, 4], [7], [2, 6, 8], [1, 7]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# to do list가 다 지워질 때까지 -> 종료조건 , 그리고 인접 노드 조사 후 들어갈때 숫자가 큰 것부터 들어감

# 탐색에 대한 DFS함수
# 입력 : 지도, 시작점
#       -- 필요한 변수 세팅 : 방문할 곳 리스트 : To Do List
#       -- 필요한 변수 세팅 : 방문한 곳 리스트 : Done List
#       ===> 시작점을 To Do List
# 사무실에서 나와서 출발!!!!!
# 큰틀 : 방문할 곳 리스트가 빌 때 까지!!!! --> 횟수X, 조건은 알 : While
#        구현) while 리스트 : 빈 리스트가 될 때 까지
#       ==> 방문할 리스트 중에서 맨 뒤에꺼 꺼내기 : Stack --> pop()
#            # 처음 방문한 곳이면 할 일 : 2가지 --> 도장/또 할일 부여 받아야 함!!1
#            1) 여기가 내가 처음 온 곳인가? ==> 도장 받기..
#                : Done list .append(뒤로 추가..)
#            2) 여기서 연결된 곳 어디가야 하나요? (또 할일 부여받기!!!)
#                :To Do List.append(뒤로 추가)

# %%
# 입력 : 지도, 시작점
# 기능 : DFS방식으로 주어진 지도를 탐색/방문하세요!!!!  깊이 먼저
# 출력 : 방문 기록을 제출

#DFS

def dfs_m1( graph, start):
    need_visit = list() # TO do list
    visited    = list() # 방문한 노드
    need_visit.append( start ) # 시작노드 집어넣기

    while need_visit: #while to_do_list를 다 지울 때까지
        node = need_visit.pop()    # to_do_list 에서 맨 뒤꺼 빼기
        if node not in visited: # <--- 신규 방문지 체크
            visited.append(node)  #방문 노드에 삽입
            need_visit.extend( sorted(graph[node],key = lambda x:-x)) # 해당 노드의 인접 노드들 조사해서 큰번호 먼저 스택에 집어넣음
    return visited

# %%
dfs_m1(graph_list, 1)
# Out:
# [1, 2, 7, 6, 8, 3, 4, 5]

# %%
# BFS방식 ( DFS에서 pop 바꾸고, 인접 노드 조사 후 삽입시 작은거 순으로 삽입) 층 먼저

# 입력 : 지도, 시작점
# 기능 : DFS방식으로 주어진 지도를 탐색/방문하세요!!!!
# 출력 : 방문 기록을 제출

def bfs_m1( graph, start):
    need_visit = list() # TO do list
    visited    = list() # 방문한 노드
    need_visit.append( start ) # 시작노드 집어넣기

    while need_visit: #while to_do_list를 다 지울 때까지
        node = need_visit.pop(0)    # to_do_list 에서 맨 앞꺼 빼기
        if node not in visited: # <--- 신규 방문지 체크
            visited.append(node)  #방문 노드에 삽입
            need_visit.extend( sorted(graph[node],key = lambda x:+x)) # 해당 노드의 인접 노드들 조사해서 작은 번호 먼저 스택에 집어넣음
    return visited

# %%
bfs_m1(graph_list, 1)
# Out:
# [1, 2, 3, 8, 7, 4, 5, 6]
